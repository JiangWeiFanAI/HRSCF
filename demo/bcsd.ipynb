# %%
from __future__ import print_function
import torch
import argparse
import sys
sys.path.append("../")

import platform
from datetime import timedelta, date, datetime
import numpy as np

import os

import time
import util.data_processing_tool as dpt

from netCDF4 import Dataset

[wj1671@gadi-login-06 eval]$ qsub bcsd.sh
25775381.gadi-pbs
# Out:
# E:\Users\Weifa\Anaconda3\envs\py37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# E:\Users\Weifa\Anaconda3\envs\py37\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# E:\Users\Weifa\Anaconda3\envs\py37\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# E:\Users\Weifa\Anaconda3\envs\py37\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
lead=2
data=Dataset('../../Data/bcsd/daily/da_pr_20121217_e01.nc')
data
var=data['bcsd'][lead].data
lat=data['lat'][:]
lon=data['lon'][:]
dpt.draw_aus_figure(var,lat,lon,title='BCSD')

data.close
# Out:
# <function Dataset.close>

# %%
data=Dataset('F:/Climate_change/Data/pr/daily/e01/da_pr_20121217_e01.nc')
var=data['pr'][lead].data
var,lat,lon=dpt.add_lat_lon_data(var)
dpt.draw_aus_figure(var*86400,lat,lon,title='ACCESS')

data.close
# Out:
# <function Dataset.close>

# %%
lead=2
data=Dataset('../../Data/bcsd/daily/da_pr_20121209_e01.nc')
data
var=data['bcsd'][lead].data
lat=data['lat'][:]
lon=data['lon'][:]
dpt.draw_aus_figure(var,lat,lon,title='BCSD')

data.close
# Out:
# <function Dataset.close>

# %%
data=Dataset('F:/Climate_change/Data/pr/daily/e01/da_pr_20121209_e01.nc')
var=data['pr'][lead].data
var,lat,lon=dpt.add_lat_lon_data(var)
dpt.draw_aus_figure(var*86400,lat,lon,title='ACCESS')

data.close
# Out:
# <function Dataset.close>

# %%
lat
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 lat(lat)
# unlimited dimensions:
# current shape = (316,)
# filling on, default _FillValue of 9.969209968386869e+36 used
